# %% [markdown]
# # Chat Model

# %% [markdown]
# * Chat models are language models that use a sequence of messages as inputs and return messages as outputs (as opposed to traditional, plaintext LLMs).

# %% [markdown]
# # use of chat model
# * Chatbots
# * Customer support AI
# * Coding help
# * Learning
# * Multi-turn reasoning
# * Complex instructions

# %% [markdown]
# # 🚀 1) Tool Calling
# * Tool Calling allows an AI model to use external tools, APIs, functions, or databases to get real results.
# * ex
# * {
#   "tool": "get_weather",
#   "city": "Ujjain"
# }

# %% [markdown]
# # 📦 2) Structured Output
# * What it means
# * Structured Output means the AI returns answers in a fixed, machine-readable format, like:
# * JSON
# * dictionaries
# * lists
# * tables
# * HTML
# * XML
# * It ensures the output never changes shape.

# %% [markdown]
# # 🖼️ 3) Multimodality
# * What it means
# * Multimodality =
# * An AI model can understand multiple types of input, not just text.
# * This includes:
# * Images
# * Audio
# * Video (in some models)
# * PDFs
# * Screenshots
# * Handwriting

# %% [markdown]
# | Feature               | What It Means                  | Why It Matters          |
# | --------------------- | ------------------------------ | ----------------------- |
# | **Tool Calling**      | AI can use external tools/APIs | Real data, real actions |
# | **Structured Output** | AI gives fixed-format output   | Reliable for coding     |
# | **Multimodality**     | AI can understand images/audio | Real-world intelligence |

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

openai_api_key = os.getenv('OPENAI_API_KEY')

# %%
from langchain_openai import OpenAI
llm = OpenAI()
response = llm.invoke('how to remove toxic girls')
response
# Out:
# "\n\n1. Recognize the signs of a toxic girl: It is important to first identify if the person you are dealing with is toxic. Some common signs of toxic behavior include manipulation, jealousy, possessiveness, constant criticism, and disrespect.\n\n2. Set boundaries: Once you have identified the toxic behavior, it is important to set clear boundaries and communicate them to the person. Let them know what behaviors are unacceptable and how you expect to be treated.\n\n3. Limit or end contact: If the toxic behavior continues, it may be necessary to limit or end contact with the person. This could mean reducing the amount of time you spend with them or cutting them out of your life completely.\n\n4. Surround yourself with positive people: Toxic people can drain your energy and bring negativity into your life. Surround yourself with positive and supportive people who uplift you and make you feel good.\n\n5. Practice self-care: It is important to take care of yourself when dealing with toxi
# ...

# %%
response.content

# %%
import os
from dotenv import load_dotenv
load_dotenv()

openai_api_key = os.getenv('OPENAI_API_KEY')

from langchain_openai import ChatOpenAI  # ← use ChatOpenAI instead of OpenAI

llm = ChatOpenAI()
response = llm.invoke('how to remove toxic people from your life')
print(response.content)  # ← use print()
# Out:
# 1. Identify toxic behavior: Take a look at the people in your life and assess their behavior. Are they consistently negative, draining your energy, manipulative or do they bring you down? These are signs of toxic behavior that you need to remove from your life.
#
# 2. Set boundaries: Once you have identified toxic people in your life, it is important to set boundaries with them. Be clear about what behavior is not acceptable to you and communicate this to them.
#
# 3. Communicate your feelings: If you feel comfortable, have a conversation with the toxic person about how their behavior is affecting you. Be honest and assertive about your feelings.
#
# 4. Spend less time with them: Limit your interactions with toxic people and avoid spending too much time with them. Surround yourself with positive and supportive people instead.
#
# ...
