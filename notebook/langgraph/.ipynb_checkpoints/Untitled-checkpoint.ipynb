# %%
from langgraph.graph import StateGraph,MessageGraph,MessagesState
from langgraph.checkpoint.memory import InMemorySaver

from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(
    base_url="http://localhost:11434",   # no space
    model="llama3.1:8b"
)

llm
# Out:
# ChatOllama(model='llama3.1:8b', base_url='http://localhost:11434')

# %% [markdown]
# Create memory (checkpointer)

# %%
checkpointer = InMemorySaver()

# %% [markdown]
# # define chatbot node

# %%
def chatbot(state: MessagesState):
    return{
        "messages":[llm.invoke(state["messages"])]
    }

# %% [markdown]
# # build the graph

# %%
builder = StateGraph(MessageGraph)

builder.add_node("chatbot",chatbot)
builder.set_entry_point("chatbot")

graph = builder.compile(checkpointer= checkpointer)

# %% [markdown]
# # define thred (memory key)

# %%
config = {
    "configurable":{
        "thread_id": "user-1"
    }
}

# %% [markdown]
# # first message

# %%
result = graph.invoke(
    {"messages":[("usser","hi")]},
    config
)
result1["messages"][-1].content
# Out:
# Ollama returned empty response with done_reason='load'.This typically indicates the model was loaded but no content was generated. Skipping this response.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 result = graph.invoke(
#       2     {"messages":[("usser","hi")]},
#       3     config
#       4 )
#       5 result1["messages"][-1].content
#
# File /opt/anaconda3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/main.py:3292, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3289             chunks.append(chunk)
#    3290 else:
#    3291     # v1: collect interrupts from updates stream
# -> 3292     for chunk in self.stream(
#    3293         input,
#    3294         config,
#    3295         context=context,
# ...

# %% [markdown]
# # secand message

# %%
result2 = graph.invoke(
    {"messages": [("user","my name is Ashish")]},
    config
)
result2["messages"][-1].content
# Out:
# Ollama returned empty response with done_reason='load'.This typically indicates the model was loaded but no content was generated. Skipping this response.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 result2 = graph.invoke(
#       2     {"messages": [("user","my name is Ashish")]},
#       3     config
#       4 )
#       5 result2["messages"][-1].content
#
# File /opt/anaconda3/envs/genai/lib/python3.10/site-packages/langgraph/pregel/main.py:3292, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3289             chunks.append(chunk)
#    3290 else:
#    3291     # v1: collect interrupts from updates stream
# -> 3292     for chunk in self.stream(
#    3293         input,
#    3294         config,
#    3295         context=context,
# ...

# %%
# import pandas as pd 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # import pandas as pd
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'
