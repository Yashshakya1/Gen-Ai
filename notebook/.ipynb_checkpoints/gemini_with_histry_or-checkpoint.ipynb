# %%
from dotenv import load_dotenv
from google import genai 
import os 
load_dotenv()

client = genai.Client(api_key= os.getenv("GEMINI_API_KEY"))

print("Gemini ChatBot with (No Memory).\n")
while True:
    user_input = input("You: ")
    if user_input.lower() in ["nekal","bhag"]:
        print("")
        break

    response = client.models.generate_content(
            model = "gemini-2.5-flash",
            contents = user_input
        )

    print("Bot:", response.text)
# Out:
# Gemini ChatBot with (No Memory).
# You:  ha
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[12], line 15
#      12     print("")
#      13     break
# ---> 15 response = client.models.generate_content(
#      16         model = "gemini-2.5-flash",
#      17         contents = user_input
#      18     )
#      20 print("Bot:", response.text)
#
# File /opt/anaconda3/lib/python3.13/site-packages/google/genai/models.py:5621, in Models.generate_content(self, model, contents, config)
#    5619 while remaining_remote_calls_afc > 0:
#    5620   i += 1
# -> 5621   response = self._generate_content(
#    5622       model=model, contents=contents, config=parsed_config
#    5623   )
#    5625   function_map = _extra_utils.get_function_map(parsed_config)
#    5626   if not function_map:
#
# ...

# %%
# !pip install google-generativeai
# from dotenv import load_dotenv
# import google.generativeai as genai
# import os

# load_dotenv()

# # Configure Gemini client
# genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

# print("Gemini ChatBot with (No Memory).\n")

# # Load the model once
# model = genai.GenerativeModel("gemini-2.5-flash")

# while True:
#     user_input = input("You: ")

#     # Exit conditions
#     if user_input.lower() in ["nekal", "bhag"]:
#         print("Chat ended.")
#         break

#     # Generate response
#     response = model.generate_content(user_input)

#     print("Bot:", response.text)

# %%
from dotenv import load_dotenv
from google import genai

load_dotenv()

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))   # correct name

print("Chatbot started > Type 'exit' or 'quit' to stop.\n")
chat = client.chats.create(model = "gemini-2.5-flash")

try:
    while True:
        user_input = input("you: ")

        if user_input.lower() in ["exit", "quit"]:
            print("Chat ended.")
            break
        

        # Generate response
        response = chat.send_message(user_input)

        bot_reply = response.text
        print("bot:", bot_reply)

        
except KeyboardInterrupt:
    print("Error:")
# Out:
# Chatbot started > Type 'exit' or 'quit' to stop.
# you:  hello
# bot: Hello! How can I help you today?
# you:  my name is ashish
# bot: Hello Ashish! It's nice to meet you.
#
# How can I help you today? Is there something specific you'd like to talk about or work on?
# you:  what is my name
# bot: Your name is Ashish.
