# %%
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()
clinet = OpenAi()

messages = [
    {'role':'system','content':'what the hell'}
]
print("chatbot start> Type 'exist or 'quit' to stop, \n")

try:
    while True:
        user_input = input("you: ")

        if user_input.lower() in ["exit","quit"]:
            print("chat ended.")
            break

        messages.append({"role":"user","content": user_input})

        response = client.chat.completions.create(
            model = "gpt-40_mini",
            messages = messages,
            temperature = 0.3
        )
# Out:
#   Cell In[2], line 25
#     )
#      ^
# _IncompleteInputError: incomplete input

# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI()   # correct name

messages = [
    {"role": "system", "content": "You are a helpful chatbot."}
]

print("Chatbot started > Type 'exit' or 'quit' to stop.\n")

try:
    while True:
        user_input = input("you: ")

        if user_input.lower() in ["exit", "quit"]:
            print("Chat ended.")
            break

        # Add user message
        messages.append({"role": "user", "content": user_input})

        # Generate response
        response = client.chat.completions.create(
            model="gpt-4o-mini",   # correct model
            messages=messages,
            temperature=0.3
        )

        bot_reply = response.choices[0].message.content
        print("bot:", bot_reply)

        # Add bot reply to message history
        messages.append({"role": "assistant", "content": bot_reply})

except Exception as e:
    print("Error:", e)

# %%
import ollama

response = ollama.chat(
    model="llama3.2",
    messages=[
        {"role": "user", "content": "What is Machine Learning AI?"}
    ]
)

print(response["message"]["content"])

# %%
from dotenv import load_dotenv
from openai import OpenAI
import os
load_dotenv()

client = OpenAI(api_key = os.getenv(""))
print("Chatbot started (No Memory)\n")

while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit","quit"]:
        
        print("Chat ended")
        break:

        response = client.responses.create(
            model="gpt-4o-mini",
            input = user_input,
        )

        print("Bot:", response.output[0].content[0].text)
# Out:
#   Cell In[9], line 14
#     break:
#          ^
# SyntaxError: invalid syntax

# %%
from dotenv import load_dotenv
from openai import OpenAI
import os

load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

print("Chatbot started (No Memory)\n")

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Chat ended")
        break

    # Generate response
    response = client.responses.create(
        model="gpt-4o-mini",
        input=user_input
    )

    print("Bot:", response.output_text)
# Out:
# Chatbot started (No Memory)
# You:  yash
# Bot: Hello! How can I assist you today, Yash?
# You:  what is madarchod
# Bot: "Madarchod" is a slang term in Hindi and other Indian languages, often used as an insult. It's considered very offensive and translates roughly to "motherf***er" in English. Such language can be derogatory and hurtful, so it's best to avoid using it in conversation. If you have questions about cultural expressions or language, feel free to ask!
# You:  exit
# Chat ended
