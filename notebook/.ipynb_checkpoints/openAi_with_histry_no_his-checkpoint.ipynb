# %%
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()
clinet = OpenAi()

messages = [
    {'role':'system','content':'what the hell'}
]
print("chatbot start> Type 'exist or 'quit' to stop, \n")

try:
    while True:
        user_input = input("you: ")

        if user_input.lower() in ["exit","quit"]:
            print("chat ended.")
            break

        messages.append({"role":"user","content": user_input})

        response = client.chat.completions.create(
            model = "gpt-40_mini",
            messages = messages,
            temperature = 0.3
        )
# Out:
#   Cell In[2], line 25
#     )
#      ^
# _IncompleteInputError: incomplete input

# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI()   # correct name

messages = [
    {"role": "system", "content": "You are a helpful chatbot."}
]

print("Chatbot started > Type 'exit' or 'quit' to stop.\n")

try:
    while True:
        user_input = input("you: ")

        if user_input.lower() in ["exit", "quit"]:
            print("Chat ended.")
            break

        # Add user message
        messages.append({"role": "user", "content": user_input})

        # Generate response
        response = client.chat.completions.create(
            model="gpt-4o-mini",   # correct model
            messages=messages,
            temperature=0.3
        )

        bot_reply = response.choices[0].message.content
        print("bot:", bot_reply)

        # Add bot reply to message history
        messages.append({"role": "assistant", "content": bot_reply})

except Exception as e:
    print("Error:", e)
# Out:
# Chatbot started > Type 'exit' or 'quit' to stop.
# you:  heloo
# bot: Hello! How can I assist you today?
# you:  hdf
# bot: It looks like your message might have been cut off or is a bit unclear. Could you please provide more details or clarify what you meant? I'm here to help!
# you:  df
# bot: It seems like your message is still unclear. If you have a specific question or topic you'd like to discuss, please let me know!
# you:  quit
# Chat ended.

# %%
import ollama

response = ollama.chat(
    model="llama3.2",
    messages=[
        {"role": "user", "content": "What is Machine Learning AI?"}
    ]
)

print(response["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ollama
#       3 response = ollama.chat(
#       4     model="llama3.2",
#       5     messages=[
#       6         {"role": "user", "content": "What is Machine Learning AI?"}
#       7     ]
#       8 )
#      10 print(response["message"]["content"])
#
# ModuleNotFoundError: No module named 'ollama'
