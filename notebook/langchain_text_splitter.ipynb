# %% [markdown]
# # 🔥 What is a Text Splitter?
# * A Text Splitter is a tool that breaks large text into smaller chunks so that LLMs can process it easily.
# # LLMs (like GPT) cannot handle very long documents directly, so we split them into:
# * ✔ small
# * ✔ meaningful
# * ✔ overlapping
# * chunks
# # types of text splitter
#   1. Character Text Splitter
#   2. Recursive Character Text Splitter
#   3. Token Text Splitter
# # 1000 tokens = 750 wards

# %% [markdown]
# # LangChain Text Splitters
#
# Text Splitters large documents ko **chunks** mein todta hai —
# taaki LLM ka context window overflow na ho.
#
# ## Types of Text Splitters
#
# | Splitter | Best For |
# |---|---|
# | `RecursiveCharacterTextSplitter` | General purpose — sabse zyada use hota |
# | `TokenTextSplitter` | Token-aware splitting |
# | `MarkdownTextSplitter` | Markdown files |
# | `PythonCodeTextSplitter` | Code |
#
# ## Chunk Size & Overlap Guide
#
# | Use Case | Chunk Size | Overlap |
# |---|---|---|
# | PDF QA | 500 | 50 |
# | Web pages | 800 | 100 |
# | Code | 300 | 50 |
# | Long documents | 1000 | 200 |

# %%
from langchain_text_splitters import CharacterTextSplitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_text_splitters import TokenTextSplitter

from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import CSVLoader
from langchain_community.document_loaders import UnstructuredPowerPointLoader
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Character text splitter

# %%
text = """ 
ai is trasnfroming insustries.
ml enables system to learn from data.
deep learning uses neuural network to detect patterns.
"""

splitter = CharacterTextSplitter(
    chunk_size =50,
    chunk_overlap=10
)
chunks = splitter.split_text(text)

chunks
# Out:
# ['ai is trasnfroming insustries.\nml enables system to learn from data.\ndeep learning uses neuural network to detect patterns.']

# %% [markdown]
# # Recursive Character TextSplitter

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 20
)
chunks = splitter.split_text(text)

chunks
# Out:
# ['ai is trasnfroming insustries.\nml enables system to learn from data.',
#  'deep learning uses neuural network to detect patterns.']

# %% [markdown]
# # Token TextSplitter

# %%
splitter = TokenTextSplitter(
    chunk_size = 30,
    chunk_overlap = 5
)
chunks = splitter.split_text(text)
chunks
# Out:
# [' \nai is trasnfroming insustries.\nml enables system to learn from data.\ndeep learning uses neuural network',
#  ' uses neuural network to detect patterns.\n']

# %% [markdown]
# # load and split a  pdf Document

# %%
loader =  PyMuPDFLoader("/Users/yashshakya787/genAI/notebook/sample_ai_document.pdf")
docs = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap =50
)

pdf_chunks = splitter.split_documents(docs)
len(pdf_chunks)
# Out:
# 2

# %% [markdown]
# # load and split a csv document

# %%
loader = CSVLoader("/Users/yashshakya787/genAI/notebook/sample_sales_data.pdf")

docs - loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size = 200,
    chunk_overlap = 20
)
csv_chunks = splitter.split_documents(docs)
len(csv_chunks)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File /opt/anaconda3/envs/genai/lib/python3.10/site-packages/langchain_community/document_loaders/csv_loader.py:135, in CSVLoader.lazy_load(self)
#     134     with open(self.file_path, newline="", encoding=self.encoding) as csvfile:
# --> 135         yield from self.__read_file(csvfile)
#     136 except UnicodeDecodeError as e:
#
# File /opt/anaconda3/envs/genai/lib/python3.10/site-packages/langchain_community/document_loaders/csv_loader.py:155, in CSVLoader.__read_file(self, csvfile)
#     154 csv_reader = csv.DictReader(csvfile, **self.csv_args)
# --> 155 for i, row in enumerate(csv_reader):
#     156     try:
#
# File /opt/anaconda3/envs/genai/lib/python3.10/csv.py:110, in DictReader.__next__(self)
#     108 if self.line_num == 0:
#     109     # Used only for its side effect.
# --> 110     self.fieldnames
# ...

# %% [markdown]
# # Load and split a ppt

# %%
loader = UnstructuredPowerPointLoader("/Users/yashshakya787/genAI/notebook/sample_ai_presentation.pptx")

docs = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size = 300,
    chunk_overlap = 30
)
ppt_chunks = splitter.split_documents(docs)
len(ppt_chunks)
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[21], line 3
#       1 loader = UnstructuredPowerPointLoader("/Users/yashshakya787/genAI/notebook/sample_ai_presentation.pptx")
# ----> 3 docs = loader.load()
#       5 splitter = RecursiveCharacterTextSplitter(
#       6     chunk_size = 300,
#       7     chunk_overlap = 30
#       8 )
#       9 ppt_chunks = splitter.split_documents(docs)
#
# File /opt/anaconda3/envs/genai/lib/python3.10/site-packages/langchain_core/document_loaders/base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# ...

# %% [markdown]
# # 7 load and split a web document

# %%
url = "https://en.wikipedia.org/wiki/Artificial_intelligence"
loader = WebBaseLoader(url)
docs = loader.load()


splitter = RecursiveCharacterTextSplitter(
    chunk_size = 800,
    chunk_overlap = 100
)
web_chunks = splitter.split_documents(docs)
len(web_chunks)
# Out:
# 372
